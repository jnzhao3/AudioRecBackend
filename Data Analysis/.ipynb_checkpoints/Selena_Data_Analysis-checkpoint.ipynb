# %%
import matplotlib as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("prosody.csv")

# %%
# def calculate(df, columns_to_remove):
#     df=df.drop(columns=columns_to_remove, axis=1)
#     df.columns.tolist()
    
#     column_sums = df.sum()
#     sorted_sums = column_sums.sort_values(ascending=False)
    
#     return sorted_sums

# %%
df = df.drop(['Id', 'Confidence', 'SpeakerConfidence'], axis=1)

# %%
df.head()
# Out:
#                                                 Text  BeginTime    EndTime  \
# 0  According to all known lodge of aviation, ther...   0.258365   5.202156
# 1  Its wings are too small to get its fat little ...   5.001446  10.025000
# 2  flies anyway because bees don't care what huma...   9.805000  13.705000
# 3  Cut to berries room where he's picking out wha...  13.925000  16.685000
# 4   Yellow black, yellow black, yellow black, yellow  16.859242  20.605085
#
#    Admiration  Adoration  Aesthetic Appreciation  Amusement     Anger  \
# 0    0.202290   0.051693                0.128334   0.230060  0.094677
# 1    0.439625   0.185282                0.712082   0.544209  0.019284
# 2    0.034329   0.047316                0.041801   0.118796  0.343090
# 3    0.051417   0.031256                0.093336   0.441520  0.206995
# 4    0.018641   0.006843                0.401761   0.084925  0.038239
#
#     Anxiety       Awe  ...   Romance   Sadness  Satisfaction    Desire  \
# 0  0.010908  0.082100  ...  0.032620  0.003200      0.059567  0.023492
# 1  0.007776  0.077538  ...  0.051254  0.001214      0.106819  0.051494
# 2  0.052831  0.006159  ...  0.067808  0.070653      0.013115  0.022503
# 3  0.087214  0.012305  ...  0.040726  0.018730      0.023773  0.033503
# 4  0.048831  0.006557  ...  0.001329  0.007838      0.011082  0.000654
#
#       Shame  Surprise (negative)  Surprise (positive)  Sympathy  Tiredness  \
# 0  0.012882             0.028202             0.024199  0.149841   0.006432
# 1  0.019365             0.005711             0.016694  0.076816   0.034777
# 2  0.168919             0.070687             0.005034  0.106949   0.007041
# 3  0.027586             0.046612             0.019892  0.143227   0.066587
# 4  0.014160             0.025955             0.014172  0.009409   0.000099
#
#     Triumph
# 0  0.093185
# 1  0.161158
# 2  0.009289
# 3  0.069626
# 4  0.187468
#
# [5 rows x 51 columns]

# %%
df
# Out:
#                                                   Text   BeginTime  \
# 0    According to all known lodge of aviation, ther...    0.258365
# 1    Its wings are too small to get its fat little ...    5.001446
# 2    flies anyway because bees don't care what huma...    9.805000
# 3    Cut to berries room where he's picking out wha...   13.925000
# 4     Yellow black, yellow black, yellow black, yellow   16.859242
# ..                                                 ...         ...
# 183      away. Dad raises his glass and says to honey.  616.819900
# 184                        Shave my antenna. So funny.  620.314470
# 185                       Shack up with a grasshopper,  622.751900
# 186   get a gold tooth and start calling everyone dog.  624.310300
# 187                                      I'm so proud.  627.706740
#
#         EndTime  Admiration  Adoration  Aesthetic Appreciation  Amusement  \
# 0      5.202156    0.202290   0.051693                0.128334   0.230060
# 1     10.025000    0.439625   0.185282                0.712082   0.544209
# 2     13.705000    0.034329   0.047316                0.041801   0.118796
# 3     16.685000    0.051417   0.031256                0.093336   0.441520
# 4     20.605085    0.018641   0.006843                0.401761   0.084925
# ..          ...         ...        ...                     ...        ...
# 183  620.059900    0.078086   0.023917                0.097917   0.361604
# 184  622.772800    0.425486   0.222843                0.306711   0.787195
# 185  624.371140    0.233203   0.087082                0.211284   0.247562
# 186  627.487900    0.040871   0.038186                0.095384   0.153747
# 187  629.286060    0.504432   0.224769                0.214465   0.098889
#
#         Anger   Anxiety       Awe  ...   Romance   Sadness  Satisfaction  \
# 0    0.094677  0.010908  0.082100  ...  0.032620  0.003200      0.059567
# 1    0.019284  0.007776  0.077538  ...  0.051254  0.001214      0.106819
# 2    0.343090  0.052831  0.006159  ...  0.067808  0.070653      0.013115
# 3    0.206995  0.087214  0.012305  ...  0.040726  0.018730      0.023773
# 4    0.038239  0.048831  0.006557  ...  0.001329  0.007838      0.011082
# ..        ...       ...       ...  ...       ...       ...           ...
# 183  0.239018  0.024490  0.020994  ...  0.020758  0.008484      0.008743
# 184  0.078713  0.020934  0.053580  ...  0.045619  0.005137      0.657054
# 185  0.039048  0.014228  0.100215  ...  0.055117  0.004821      0.301340
# 186  0.276097  0.022641  0.016235  ...  0.015057  0.007078      0.023913
# 187  0.066450  0.110537  0.087435  ...  0.023239  0.031524      0.390912
#
#        Desire     Shame  Surprise (negative)  Surprise (positive)  Sympathy  \
# 0    0.023492  0.012882             0.028202             0.024199  0.149841
# 1    0.051494  0.019365             0.005711             0.016694  0.076816
# 2    0.022503  0.168919             0.070687             0.005034  0.106949
# 3    0.033503  0.027586             0.046612             0.019892  0.143227
# 4    0.000654  0.014160             0.025955             0.014172  0.009409
# ..        ...       ...                  ...                  ...       ...
# 183  0.051929  0.018026             0.045798             0.030522  0.180944
# 184  0.078915  0.064512             0.030444             0.110477  0.103798
# 185  0.063450  0.023805             0.044398             0.122643  0.055313
# 186  0.014148  0.091766             0.013051             0.020635  0.037574
# 187  0.028430  0.081327             0.040116             0.068255  0.035725
#
#      Tiredness   Triumph
# 0     0.006432  0.093185
# 1     0.034777  0.161158
# 2     0.007041  0.009289
# 3     0.066587  0.069626
# 4     0.000099  0.187468
# ..         ...       ...
# 183   0.037489  0.024330
# 184   0.055451  0.126000
# 185   0.062397  0.100932
# 186   0.015162  0.062887
# 187   0.083435  0.073821
#
# [188 rows x 51 columns]

# %%
total_row = df.copy()
total_row.loc['Total'] = total_row[total_row.columns[3:]].sum()
total_row.tail()
# Out:
#                                                    Text  BeginTime    EndTime  \
# 184                         Shave my antenna. So funny.  620.31447  622.77280
# 185                        Shack up with a grasshopper,  622.75190  624.37114
# 186    get a gold tooth and start calling everyone dog.  624.31030  627.48790
# 187                                       I'm so proud.  627.70674  629.28606
# Total                                               NaN        NaN        NaN
#
#        Admiration  Adoration  Aesthetic Appreciation  Amusement      Anger  \
# 184      0.425486   0.222843                0.306711   0.787195   0.078713
# 185      0.233203   0.087082                0.211284   0.247562   0.039048
# 186      0.040871   0.038186                0.095384   0.153747   0.276097
# 187      0.504432   0.224769                0.214465   0.098889   0.066450
# Total   37.296901  23.586625               30.891640  91.850382  35.694630
#
#          Anxiety        Awe  ...   Romance   Sadness  Satisfaction    Desire  \
# 184     0.020934   0.053580  ...  0.045619  0.005137      0.657054  0.078915
# 185     0.014228   0.100215  ...  0.055117  0.004821      0.301340  0.063450
# 186     0.022641   0.016235  ...  0.015057  0.007078      0.023913  0.014148
# 187     0.110537   0.087435  ...  0.023239  0.031524      0.390912  0.028430
# Total  16.654429  15.213168  ...  7.279826  3.168124     29.046522  7.460576
#
#           Shame  Surprise (negative)  Surprise (positive)   Sympathy  \
# 184    0.064512             0.030444             0.110477   0.103798
# 185    0.023805             0.044398             0.122643   0.055313
# 186    0.091766             0.013051             0.020635   0.037574
# 187    0.081327             0.040116             0.068255   0.035725
# Total  7.810489            21.474806            30.685194  18.676248
#
#        Tiredness    Triumph
# 184     0.055451   0.126000
# 185     0.062397   0.100932
# 186     0.015162   0.062887
# 187     0.083435   0.073821
# Total   7.249443  21.760080
#
# [5 rows x 51 columns]

# %%
sorted_totals = total_row.sort_values('Total', axis=1, ascending=False)
sorted_totals
# Out:
#        Amusement  Excitement   Interest  Determination   Contempt  \
# 0       0.230060    0.064954   0.168806       0.378135   0.610941
# 1       0.544209    0.148892   0.115798       0.197066   0.249009
# 2       0.118796    0.001011   0.022823       0.028267   0.874842
# 3       0.441520    0.090172   0.338498       0.418627   0.307831
# 4       0.084925    0.337640   0.026056       0.147508   0.027170
# ...          ...         ...        ...            ...        ...
# 184     0.787195    0.380632   0.436964       0.060900   0.178208
# 185     0.247562    0.439586   0.572432       0.375354   0.123768
# 186     0.153747    0.202811   0.088800       0.209424   0.331420
# 187     0.098889    0.058346   0.063215       0.120747   0.110769
# Total  91.850382   60.562884  51.885458      47.107847  44.538406
#
#        Realization  Awkwardness    Disgust  Contemplation  Admiration  ...  \
# 0         0.437385     0.028604   0.173933       0.786751    0.202290  ...
# 1         0.099058     0.057876   0.520660       0.387237    0.439625  ...
# 2         0.079523     0.085690   0.913536       0.573093    0.034329  ...
# 3         0.180885     0.133908   0.253808       0.216090    0.051417  ...
# 4         0.006281     0.037551   0.146667       0.057209    0.018641  ...
# ...            ...          ...        ...            ...         ...  ...
# 184       0.044222     0.131737   0.102482       0.016616    0.425486  ...
# 185       0.234691     0.033904   0.184943       0.046683    0.233203  ...
# 186       0.072090     0.080497   0.563210       0.074271    0.040871  ...
# 187       0.027118     0.184699   0.081879       0.015524    0.504432  ...
# Total    44.510432    40.130603  38.402310      37.430656   37.296901  ...
#
#         Romance  Tiredness  Empathic Pain      Fear    Horror      Pain  \
# 0      0.032620   0.006432       0.024588  0.004924  0.009626  0.003289
# 1      0.051254   0.034777       0.021735  0.004902  0.014231  0.005222
# 2      0.067808   0.007041       0.068153  0.004718  0.010235  0.006592
# 3      0.040726   0.066587       0.059548  0.024703  0.014339  0.016920
# 4      0.001329   0.000099       0.003503  0.029793  0.036716  0.008562
# ...         ...        ...            ...       ...       ...       ...
# 184    0.045619   0.055451       0.031623  0.022188  0.028620  0.016065
# 185    0.055117   0.062397       0.031030  0.024461  0.049414  0.009925
# 186    0.015057   0.015162       0.016426  0.004693  0.010583  0.016086
# 187    0.023239   0.083435       0.036371  0.047020  0.023492  0.033577
# Total  7.279826   7.249443       7.183139  6.887566  6.308678  4.104220
#
#         Sadness                                               Text  \
# 0      0.003200  According to all known lodge of aviation, ther...
# 1      0.001214  Its wings are too small to get its fat little ...
# 2      0.070653  flies anyway because bees don't care what huma...
# 3      0.018730  Cut to berries room where he's picking out wha...
# 4      0.007838   Yellow black, yellow black, yellow black, yellow
# ...         ...                                                ...
# 184    0.005137                        Shave my antenna. So funny.
# 185    0.004821                       Shack up with a grasshopper,
# 186    0.007078   get a gold tooth and start calling everyone dog.
# 187    0.031524                                      I'm so proud.
# Total  3.168124                                                NaN
#
#         BeginTime     EndTime
# 0        0.258365    5.202156
# 1        5.001446   10.025000
# 2        9.805000   13.705000
# 3       13.925000   16.685000
# 4       16.859242   20.605085
# ...           ...         ...
# 184    620.314470  622.772800
# 185    622.751900  624.371140
# 186    624.310300  627.487900
# 187    627.706740  629.286060
# Total         NaN         NaN
#
# [189 rows x 51 columns]

# %%
tags = list(sorted_totals.columns[:5])
tags
# Out:
# ['Amusement', 'Excitement', 'Interest', 'Determination', 'Contempt']

# %%
flattened = df[df.columns[3:]].idxmax(axis=1)
# flattened.drop(flattened.tail(1).index,inplace=True)
# flattened['Associated'] = df['Text'].values
flattened.tail()
# Out:
# 183    Contemplation
# 184        Amusement
# 185         Calmness
# 186          Disgust
# 187            Pride
# dtype: object

# %%
type(flattened)
# Out:
# pandas.core.series.Series

# %%
text_total = df.copy()
text_total['Emotion'] = flattened

# %%
text_total.head()
# Out:
#                                                 Text  BeginTime    EndTime  \
# 0  According to all known lodge of aviation, ther...   0.258365   5.202156
# 1  Its wings are too small to get its fat little ...   5.001446  10.025000
# 2  flies anyway because bees don't care what huma...   9.805000  13.705000
# 3  Cut to berries room where he's picking out wha...  13.925000  16.685000
# 4   Yellow black, yellow black, yellow black, yellow  16.859242  20.605085
#
#    Admiration  Adoration  Aesthetic Appreciation  Amusement     Anger  \
# 0    0.202290   0.051693                0.128334   0.230060  0.094677
# 1    0.439625   0.185282                0.712082   0.544209  0.019284
# 2    0.034329   0.047316                0.041801   0.118796  0.343090
# 3    0.051417   0.031256                0.093336   0.441520  0.206995
# 4    0.018641   0.006843                0.401761   0.084925  0.038239
#
#     Anxiety       Awe  ...   Sadness  Satisfaction    Desire     Shame  \
# 0  0.010908  0.082100  ...  0.003200      0.059567  0.023492  0.012882
# 1  0.007776  0.077538  ...  0.001214      0.106819  0.051494  0.019365
# 2  0.052831  0.006159  ...  0.070653      0.013115  0.022503  0.168919
# 3  0.087214  0.012305  ...  0.018730      0.023773  0.033503  0.027586
# 4  0.048831  0.006557  ...  0.007838      0.011082  0.000654  0.014160
#
#    Surprise (negative)  Surprise (positive)  Sympathy  Tiredness   Triumph  \
# 0             0.028202             0.024199  0.149841   0.006432  0.093185
# 1             0.005711             0.016694  0.076816   0.034777  0.161158
# 2             0.070687             0.005034  0.106949   0.007041  0.009289
# 3             0.046612             0.019892  0.143227   0.066587  0.069626
# 4             0.025955             0.014172  0.009409   0.000099  0.187468
#
#                   Emotion
# 0           Contemplation
# 1  Aesthetic Appreciation
# 2                 Disgust
# 3               Amusement
# 4  Aesthetic Appreciation
#
# [5 rows x 52 columns]

# %%
by_emotion = text_total.copy()
by_emotion = by_emotion[['Emotion', 'Text']]

by_emotion = by_emotion.groupby('Emotion', as_index = True).agg({'Text': ' '.join})
by_emotion.head()
# Out:
#                                                                      Text
# Emotion
# Admiration              Here's the graduate. We're very proud of you s...
# Aesthetic Appreciation  Its wings are too small to get its fat little ...
# Amusement               Cut to berries room where he's picking out wha...
# Anger                   Ow, that's me. That girl was hot. She's my cou...
# Awe                     then does a loop on my road. Wow. Wow. That bl...

# %%
from collections import Counter

# %%
def create_pie(emotions):
    "Admiration": "#", 

    "Adoration": "#F6C8CD", 

    "Aesthetic Appreciation": "#", 

    "Amusement": "#", 

    "Anger": "#", 

    "Anxiety": "#", 

    "Awe": "#", 

    "Awkwardness": "#", 

    "Boredom": "#", 

    "Calmness": "#", 

    "Concentration": "#", 

    "Contemplation": "#", 

    "Confusion": "#", 

    "Contempt": "#", 

    "Contentment": "#", 

    "Craving": "#", 

    "Determination": "#", 

    "Disappointment": "#", 

    "Disgust": "#", 

    "Distress": "#", 

    "Doubt": "#", 

    "Ecstasy": "#", 

    "Embarrassment": "#", 

    "Empathic Pain": "#", 

    "Entrancement": "#", 

    "Envy": "#", 

    "Excitement": "#", 

    "Fear": "#", 

    "Guilt": "#", 

    "Horror": "#", 

    "Interest": "#", 

    "Joy": "#", 

    "Love": "#", 

    "Nostalgia": "#", 

    "Pain": "#", 

    "Pride": "#", 

    "Realization": "#", 

    "Relief": "#", 

    "Romance": "#", 

    "Sadness": "#", 

    "Satisfaction": "#", 

    "Desire": "#", 

    "Shame": "#", 

    "Surprise (negative)": "#", 

    "Surprise (positive)": "#", 

    "Sympathy": "#", 

    "Tiredness": "#", 

    "Triumph": "#",
# Out:
#   Cell In[91], line 2
#     "Admiration": "#",
#     ^
# SyntaxError: illegal target for annotation

# %%
# by_emotion.loc['Awe']['Text']
word_frequencies = Counter(str(by_emotion.loc['Amusement']['Text']).split()).most_common()
word_frequencies = [s for s in word_frequencies if (len(s[0]) > 2 and s[0] not in ['the', 'you', 'and', 'are', 'for'])]
word_frequencies.sort(key=lambda x: x[1], reverse=True)
word_frequencies
# Out:
# [('into', 10),
#  ('honey', 6),
#  ('that', 6),
#  ('just', 6),
#  ('out', 5),
#  ('back', 5),
#  ('Oh,', 4),
#  ('his', 4),
#  ('You', 4),
#  ('Hey,', 4),
#  ('with', 4),
#  ('not', 4),
#  ('Yeah.', 3),
#  ('from', 3),
#  ('your', 3),
#  ('around', 3),
#  ('drive', 3),
#  ('gonna', 3),
#  ('flies', 3),
#  ('down', 3),
#  ('honey.', 3),
#  ('hit', 3),
#  ('about', 3),
#  ('funny.', 3),
#  ("You're", 3),
#  ("he's", 2),
#  ('what', 2),
#  ('Berry', 2),
#  ('style', 2),
#  ('Barry,', 2),
#  ('while', 2),
#  ('stop', 2),
#  ('Barry', 2),
#  ('pick', 2),
#  ('Barry.', 2),
#  ('make', 2),
#  ('it.', 2),
#  ('hive.', 2),
#  ('they', 2),
#  ('their', 2),
#  ('Are', 2),
#  ('our', 2),
#  ('jobs', 2),
#  ('going', 2),
#  ('little', 2),
#  ('bee', 2),
#  ('forth', 2),
#  ('magazine', 2),
#  ('water', 2),
#  ('two', 2),
#  ('but', 2),
#  ('The', 2),
#  ('converts', 2),
#  ('say', 2),
#  ('One', 2),
#  ('job', 2),
#  ("That's", 2),
#  ('have', 2),
#  ('Wait', 2),
#  ('out.', 2),
#  ('lady', 2),
#  ('wearing', 2),
#  ('see', 2),
#  ('it,', 2),
#  ('had', 2),
#  ('And', 2),
#  ('think', 2),
#  ('get', 2),
#  ('me.', 2),
#  ('stir.', 2),
#  ('Cut', 1),
#  ('berries', 1),
#  ('room', 1),
#  ('where', 1),
#  ('picking', 1),
#  ('wear.', 1),
#  ('black.', 1),
#  ('black', 1),
#  ('yellow.', 1),
#  ("Let's", 1),
#  ('shake', 1),
#  ('little.', 1),
#  ('used', 1),
#  ('dispenser', 1),
#  ('hair,', 1),
#  ('phone', 1),
#  ('rings.', 1),
#  ('hang', 1),
#  ('second.', 1),
#  ('use', 1),
#  ('stairs,', 1),
#  ('father', 1),
#  ('paid', 1),
#  ('good', 1),
#  ('got', 1),
#  ('some', 1),
#  ('lint', 1),
#  ('fuzz.', 1),
#  ('Wave', 1),
#  ('us.', 1),
#  ("We'll", 1),
#  ('row.', 1),
#  ('told', 1),
#  ('flying', 1),
#  ('house.', 1),
#  ('drives', 1),
#  ('car', 1),
#  ('class.', 1),
#  ('Adam.', 1),
#  ('fuzz', 1),
#  ('gel?', 1),
#  ('Never', 1),
#  ('thought', 1),
#  ("I'd", 1),
#  ('Three', 1),
#  ('days', 1),
#  ('hitch', 1),
#  ('hiked', 1),
#  ('did', 1),
#  ('come', 1),
#  ('different.', 1),
#  ('calls', 1),
#  ('pass.', 1),
#  ('Hi,', 1),
#  ('Already', 1),
#  ('Going', 1),
#  ('Bee', 1),
#  ('men,', 1),
#  ('bumping', 1),
#  ('each', 1),
#  ('other.', 1),
#  ('Please', 1),
#  ('welcome', 1),
#  ('Dean', 1),
#  ('Bo.', 1),
#  ('Students', 1),
#  ('cheer', 1),
#  ('throw', 1),
#  ('caps', 1),
#  ('air', 1),
#  ('helmets', 1),
#  ('placed', 1),
#  ('onto', 1),
#  ('heads', 1),
#  ('begin,', 1),
#  ('career', 1),
#  ('industries,', 1),
#  ('today?', 1),
#  ('heard', 1),
#  ("it's", 1),
#  ('orientation.', 1),
#  ('whoa.', 1),
#  ('Heads', 1),
#  ('up.', 1),
#  ('Here', 1),
#  ('go.', 1),
#  ('trauma', 1),
#  ('starts', 1),
#  ('moving', 1),
#  ('pizza', 1),
#  ('Spanish.', 1),
#  ('Wonder', 1),
#  ('like', 1),
#  ('scary.', 1),
#  ('Hand', 1),
#  ('berry', 1),
#  ('mimics', 1),
#  ('shiver', 1),
#  ('making', 1),
#  ('scared', 1),
#  ('noises.', 1),
#  ('its', 1),
#  ('distinctive', 1),
#  ('golden', 1),
#  ('glow', 1),
#  ('know', 1),
#  ('guide', 1),
#  ('grabs', 1),
#  ('beak', 1),
#  ('toss', 1),
#  ('Behind', 1),
#  ('display', 1),
#  ('window,', 1),
#  ('puts', 1),
#  ('helmet', 1),
#  ('then', 1),
#  ('runs', 1),
#  ('levers', 1),
#  ('holding', 1),
#  ('rolled', 1),
#  ('she', 1),
#  ('moved', 1),
#  ('try', 1),
#  ('him.', 1),
#  ('has', 1),
#  ('lam', 1),
#  ('dodges', 1),
#  ('water,', 1),
#  ('cans.', 1),
#  ('signals', 1),
#  ('okay,', 1),
#  ('flattened', 1),
#  ('Magazine', 1),
#  ('shu', 1),
#  ('strand', 1),
#  ('hangs', 1),
#  ('after', 1),
#  ('port.', 1),
#  ('Saved', 1),
#  ('millions.', 1),
#  ('Can', 1),
#  ('anyone', 1),
#  ('work', 1),
#  ('coleman?', 1),
#  ('course,', 1),
#  ('most', 1),
#  ('small', 1),
#  ('Everyone', 1),
#  ('laughs', 1),
#  ('looks', 1),
#  ('uncomfortable.', 1),
#  ('tram', 1),
#  ('boat', 1),
#  ('flows', 1),
#  ('log', 1),
#  ('flu', 1),
#  ('ramp', 1),
#  ('Then', 1),
#  ('How', 1),
#  ('can', 1),
#  ('that?', 1),
#  ('forever.', 1),
#  ('insane', 1),
#  ('choice', 1),
#  ('filling', 1),
#  ('station', 1),
#  ('attendant', 1),
#  ('yells', 1),
#  ('putting', 1),
#  ('nozzle', 1),
#  ('own', 1),
#  ('mouth.', 1),
#  ('Both', 1),
#  ('middle', 1),
#  ('intersection.', 1),
#  ('traffic', 1),
#  ('them.', 1),
#  ('approach.', 1),
#  ('second', 1),
#  ('check', 1),
#  ('Hey.', 1),
#  ('Those', 1),
#  ('Paul', 1),
#  ('jo.', 1),
#  ('Wow.', 1),
#  ('Pal', 1),
#  ('fly', 1),
#  ('high', 1),
#  ('land.', 1),
#  ("I've", 1),
#  ('never', 1),
#  ('seen', 1),
#  ('them', 1),
#  ('this', 1),
#  ('close.', 1),
#  ('Two', 1),
#  ("b's", 1),
#  ('wave', 1),
#  ('jackson', 1),
#  ('call', 1),
#  ('Hi.', 1),
#  ('removed', 1),
#  ('collected', 1),
#  ('storage', 1),
#  ('capsules', 1),
#  ('Perhaps,', 1),
#  ('unless', 1),
#  ("you're", 1),
#  ('same', 1),
#  ('ladies,', 1),
#  ('yeah.', 1),
#  ('time', 1),
#  ('bear', 1),
#  ('pinned', 1),
#  ('against', 1),
#  ('mushroom.', 1),
#  ('one', 1),
#  ('pawn', 1),
#  ('throat.', 1),
#  ('other', 1),
#  ('was', 1),
#  ('slapping', 1),
#  ('across', 1),
#  ('face.', 1),
#  ('my.', 1),
#  ('want.', 1),
#  ('gus', 1),
#  ('there', 1),
#  ('today.', 1),
#  ("Wasn't", 1),
#  ('knit', 1),
#  ('Comrade.', 1),
#  ("We're", 1),
#  ('sunflower', 1),
#  ('patch', 1),
#  ('six', 1),
#  ('miles', 1),
#  ('here', 1),
#  ('tomorrow.', 1),
#  ('Six', 1),
#  ('miles.', 1),
#  ('Mary,', 1),
#  ('What', 1),
#  ('Buzzing', 1),
#  ('boy?', 1),
#  ('enough?', 1),
#  ('Later', 1),
#  ('home', 1),
#  ('night,', 1),
#  ('balcony', 1),
#  ('looking', 1),
#  ('Well', 1),
#  ("there's", 1),
#  ('lot', 1),
#  ('choices.', 1),
#  ('But', 1),
#  ('only', 1),
#  ('one,', 1),
#  ('Son', 1),
#  ('let', 1),
#  ('tell', 1),
#  ('something', 1),
#  ('stirring.', 1),
#  ('grab', 1),
#  ('stick', 1),
#  ('move', 1),
#  ('stir', 1),
#  ('around.', 1),
#  ('yourself', 1),
#  ('rhythm.', 1),
#  ("It's", 1),
#  ('beautiful', 1),
#  ('thing.', 1),
#  ('know,', 1),
#  ('dad,', 1),
#  ('more', 1),
#  ('maybe', 1),
#  ('field', 1),
#  ("isn't", 1),
#  ('Right', 1),
#  ('thinking', 1),
#  ('what?', 1),
#  ('Making', 1),
#  ('balloon', 1),
#  ('animals?', 1),
#  ('bad', 1),
#  ('guy', 1),
#  ('sting.', 1),
#  ('Janet,', 1),
#  ("son's", 1),
#  ('sure', 1),
#  ('wants', 1),
#  ('Berry,', 1),
#  ('funny', 1),
#  ('sometimes.', 1),
#  ("I'm", 1),
#  ('trying', 1),
#  ('Our', 1),
#  ('sun', 1),
#  ("one's", 1),
#  ('listening', 1),
#  ('until', 1),
#  ('sticks', 1),
#  ('you.', 1),
#  ('could', 1),
#  ('anything', 1),
#  ('want', 1),
#  ('right', 1),
#  ('now', 1),
#  ('sings', 1),
#  ('song.', 1),
#  ('Maybe', 1),
#  ("I'll", 1),
#  ('pierce', 1),
#  ('thor.', 1),
#  ('Mom', 1),
#  ('dad', 1),
#  ('start', 1),
#  ('walking', 1),
#  ('Shave', 1),
#  ('antenna.', 1)]

# %%
import matplotlib.pyplot as plt

# fig, ax = plt.subplots()
# ax.bar([s[0] for s in word_frequencies], align="center", height=90)
# # ax.set_xticks(range(len(l)))
# ax.set_xticklabels([s[1] for s in word_frequencies])

labsl, values = zip(*word_frequencies)
plt.bar(labels, values)

# plt.plot(word_frequencies)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[249], line 8
#       1 import matplotlib.pyplot as plt
#       3 # fig, ax = plt.subplots()
#       4 # ax.bar([s[0] for s in word_frequencies], align="center", height=90)
#       5 # # ax.set_xticks(range(len(l)))
#       6 # ax.set_xticklabels([s[1] for s in word_frequencies])
# ----> 8 plt.plot(word_frequencies)
#      10 plt.show()
#
# File ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/axes/_base.py:501, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     499     self.axes.xaxis.update_units(x)
#     500 if self.axes.yaxis is not None:
# --> 501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
#     504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#
# File ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/axis.py:1675, in Axis.update_units(self, data)
#    1673 neednew = self.converter != converter
#    1674 self.converter = converter
# -> 1675 default = self.converter.default_units(data, self)
#    1676 if default is not None and self.units is None:
#    1677     self.set_units(default)
#
# File ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/category.py:181, in UnitData.__init__(self, data)
#     179 self._counter = itertools.count()
#     180 if data is not None:
# --> 181     self.update(data)
#
# File ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/category.py:214, in UnitData.update(self, data)
#     212 # check if convertible to number:
#     213 convertible = True
# --> 214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
#     216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#
# TypeError: unhashable type: 'numpy.ndarray'
